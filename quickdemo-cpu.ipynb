# %% [markdown]
# ## Interactively install packages as needed
#
# The below cells show how to install/upgrade packages on the cluster using pip, interactively. No kernel restart needed.

# %%
import os
import dask
from dask.distributed import Client
from azureml.core import Run

# %%
packages = 'matplotlib'

def update_packages(packages):
    os.system(f'pip install --upgrade {packages}')

# %%
run   = Run.get_context()
nodes = run.get_metrics()['nodes']

# %%
c = Client(f'{run.get_metrics()["scheduler"]}')
c
# Out:
# <Client: 'tcp://10.11.0.26:8786' processes=25 threads=200, memory=1.48 TB>

# %%
to_compute = dask.delayed([dask.delayed(update_packages)(packages) for i in range(nodes)])
to_compute.compute();

# %%
c.restart()
# Out:
# <Client: 'tcp://10.11.0.26:8786' processes=0 threads=0, memory=0 B>

# %% [markdown]
# ## Connect to cluster

# %%
import os
import glob
import dask
import time
import joblib
import fsspec
import socket
import matplotlib

import pandas as pd
import dask.dataframe as dd
import matplotlib.pyplot as plt

from datetime import datetime
from dask.distributed import Client
from IPython.core.display import HTML
from dask_ml.xgboost import XGBRegressor

from azureml.core import Run, Model

# %matplotlib inline

# %%
run = Run.get_context()
run
# Out:
# Run(Experiment: dask-demo,
# Id: dask-demo_1581036271_b9dadf22,
# Type: azureml.scriptrun,
# Status: Running)

# %%
c = Client(f'{run.get_metrics()["scheduler"]}')
c
# Out:
# <Client: 'tcp://10.11.0.26:8786' processes=25 threads=200, memory=1.48 TB>

# %% [markdown]
# ## Read data
#
# Conveniently, the datastore is mounted so it can be viewed/operated on as if local. However, for reading into the distributed cluster, we will use ADLS's HDFS driver.

# %%
STORAGE_OPTIONS = {
    'account_name': run.experiment.workspace.datastores['gen2'].account_name,
    'account_key' : run.experiment.workspace.datastores['gen2'].account_key
}

protocol  = 'abfs'      # change to 'adl' for gen 1
container = 'datasets'

# %%
files = glob.glob('../../../gen2/noaa-isd/year=*/month=*/*.parquet') # may need adjustment - should use run.get_metrics()['data_store'] to get the path 
files = [f'{protocol}://{container}/{file[14:]}' for file in files]  # may need adjustment 
files[-5:]
# Out:
# ['abfs://datasets/noaa-isd/year=2020/month=2/part-00003-tid-6801200040526966564-718674ed-d761-44e0-8de6-14f684b68a23-1890-2.c000.snappy.parquet',
#  'abfs://datasets/noaa-isd/year=2020/month=2/part-00004-tid-6801200040526966564-718674ed-d761-44e0-8de6-14f684b68a23-1888-2.c000.snappy.parquet',
#  'abfs://datasets/noaa-isd/year=2020/month=2/part-00005-tid-6801200040526966564-718674ed-d761-44e0-8de6-14f684b68a23-1889-2.c000.snappy.parquet',
#  'abfs://datasets/noaa-isd/year=2020/month=2/part-00006-tid-6801200040526966564-718674ed-d761-44e0-8de6-14f684b68a23-1887-2.c000.snappy.parquet',
#  'abfs://datasets/noaa-isd/year=2020/month=2/part-00007-tid-6801200040526966564-718674ed-d761-44e0-8de6-14f684b68a23-1891-2.c000.snappy.parquet']

# %%
df = dd.read_parquet(files, engine='pyarrow', storage_options=STORAGE_OPTIONS).repartition(npartitions=200).persist()
# %time df.head()
# Out:
# CPU times: user 306 ms, sys: 6.07 ms, total: 312 ms
# Wall time: 1min 24s
#      usaf   wban            datetime  latitude  longitude  elevation  \
# 0  999999  53878 2008-01-10 18:30:00    35.419    -82.557      641.0
# 1  999999  53877 2008-01-06 13:45:00    35.495    -82.614      656.0
# 2  999999  53878 2008-01-29 14:35:00    35.419    -82.557      641.0
# 3  999999  53877 2008-01-04 05:25:00    35.495    -82.614      656.0
# 4  999999  53878 2008-01-12 00:30:00    35.419    -82.557      641.0
#
#    windAngle  windSpeed  temperature  seaLvlPressure  ...  \
# 0        NaN        NaN          7.4             NaN  ...
# 1        NaN        NaN          1.4             NaN  ...
# 2        NaN        NaN          7.3             NaN  ...
# 3        NaN        NaN        -11.4             NaN  ...
# 4        NaN        NaN          5.7             NaN  ...
#
#   pastWeatherIndicator  precipTime  precipDepth  snowDepth      stationName  \
# 0                  NaN         NaN          NaN        NaN   ASHEVILLE 13 S
# 1                  NaN         NaN          NaN        NaN  ASHEVILLE 8 SSW
# 2                  NaN         NaN          NaN        NaN   ASHEVILLE 13 S
# 3                  NaN         NaN          NaN        NaN  ASHEVILLE 8 SSW
# 4                  NaN         NaN          NaN        NaN   ASHEVILLE 13 S
#
#    countryOrRegion           p_k  year day  version
# 0               US  999999-53878  2008  10      1.0
# 1               US  999999-53877  2008   6      1.0
# 2               US  999999-53878  2008  29      1.0
# 3               US  999999-53877  2008   4      1.0
# 4               US  999999-53878  2008  12      1.0
#
# [5 rows x 22 columns]

# %%
df = df.set_index(dd.to_datetime(df.datetime).dt.floor('d'), sorted=True).persist()
# %time len(df)
# Out:
# /azureml-envs/azureml_d2ba0c6c1f746ec598174ceaba2cb94d/lib/python3.6/site-packages/dask/dataframe/shuffle.py:726: UserWarning: Partition indices have overlap.
#   warnings.warn("Partition indices have overlap.")
# CPU times: user 437 ms, sys: 20.6 ms, total: 458 ms
# Wall time: 2min 31s
# 1418912389

# %%
# %time len(df)
# Out:
# CPU times: user 128 ms, sys: 16.2 ms, total: 145 ms
# Wall time: 407 ms
# 1418912389

# %% [markdown]
# ## Explore data

# %%
# %time df.describe().compute()
# Out:
# CPU times: user 12 s, sys: 200 ms, total: 12.2 s
# Wall time: 2min 58s
#            latitude     longitude     elevation     windAngle     windSpeed  \
# count  1.418912e+09  1.418912e+09  1.418912e+09  1.137399e+09  1.181244e+09
# mean   3.743931e+01 -3.953055e+01  3.978392e+02  1.650935e+02  3.435236e+00
# std    2.155519e+01  7.852701e+01  6.269809e+02  1.145642e+02  2.865857e+00
# min   -9.000000e+01 -1.799990e+02 -3.880000e+02  0.000000e+00  0.000000e+00
# 25%    3.405000e+01 -9.526000e+01  4.500000e+01  8.000000e+01  2.000000e+00
# 50%    4.161600e+01 -7.112400e+01  2.000000e+02  2.100000e+02  3.600000e+00
# 75%    4.916700e+01  1.750000e+01  5.490000e+02  2.800000e+02  5.700000e+00
# max    8.733300e+01  9.999990e+02  9.999000e+03  3.600000e+02  9.000000e+01
#
#         temperature  seaLvlPressure  presentWeatherIndicator  \
# count  1.392221e+09    5.040201e+08             1.284247e+08
# mean   1.192928e+01    1.014686e+03             2.979781e+01
# std    1.249716e+01    9.377442e+00             2.929555e+01
# min   -9.130000e+01    8.600000e+02             0.000000e+00
# 25%    8.400000e+00    1.011700e+03             1.000000e+01
# 50%    1.600000e+01    1.017100e+03             5.000000e+01
# 75%    2.780000e+01    1.026000e+03             7.100000e+01
# max    6.170000e+01    1.090000e+03             9.900000e+01
#
#        pastWeatherIndicator    precipTime   precipDepth     snowDepth  \
# count          5.264354e+07  2.985855e+08  2.985855e+08  8.233231e+06
# mean           4.264959e+00  9.384185e+00  1.071676e+03  1.807652e+01
# std            2.999960e+00  2.027842e+01  3.078596e+03  3.332099e+01
# min            0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%            2.000000e+00  1.000000e+00  0.000000e+00  1.000000e+00
# 50%            6.000000e+00  1.000000e+00  0.000000e+00  1.500000e+01
# 75%            8.000000e+00  1.200000e+01  9.999000e+03  6.200000e+01
# max            9.000000e+00  9.900000e+01  9.999000e+03  9.990000e+02
#
#                year           day       version
# count  1.418912e+09  1.418912e+09  1.418912e+09
# mean   2.013845e+03  1.570915e+01  1.000000e+00
# std    3.441802e+00  8.820229e+00  0.000000e+00
# min    2.008000e+03  1.000000e+00  1.000000e+00
# 25%    2.012000e+03  8.000000e+00  1.000000e+00
# 50%    2.016000e+03  1.600000e+01  1.000000e+00
# 75%    2.020000e+03  2.400000e+01  1.000000e+00
# max    2.020000e+03  3.100000e+01  1.000000e+00

# %%
# %time places = df.groupby(df.index)[['longitude', 'latitude', 'year']].mean().compute()
# Out:
# CPU times: user 534 ms, sys: 29.5 ms, total: 563 ms
# Wall time: 3min 13s

# %%
plt.figure(figsize=(16, 16))
plt.scatter(places.longitude, places.latitude, c=places.year)
plt.title('Lat/long')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid()
plt.colorbar()

# %%
plt.figure(figsize=(16, 16))
plt.scatter(places.longitude, places.latitude, c=places.year)
plt.title('Lat/long')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.xlim([-50, -30]) # zoom in 
plt.ylim([35, 40])   # zoom in 
plt.grid()
plt.colorbar()

run.log_image(f'lat_long_zoomed', plot=plt) # log image to run

# %%
# %time means = df.groupby(df.index).mean().compute()
means.head()
# Out:
# CPU times: user 841 ms, sys: 93.1 ms, total: 934 ms
# Wall time: 5min 10s
#              latitude  longitude   elevation   windAngle  windSpeed  \
# 2008-01-01  37.851544 -41.404520  351.706004  176.364994   4.031225
# 2008-01-02  37.774122 -40.943714  352.504602  180.436673   4.306232
# 2008-01-03  37.781321 -40.130623  352.634351  156.904648   4.358461
# 2008-01-04  37.879647 -40.516726  353.027684  149.716467   4.318913
# 2008-01-05  37.956239 -41.565558  358.450412  161.096456   4.328847
#
#             temperature  seaLvlPressure  presentWeatherIndicator  \
# 2008-01-01     0.791217     1021.312605                29.191647
# 2008-01-02    -0.932920     1021.165374                32.632597
# 2008-01-03    -0.866068     1020.247739                32.471547
# 2008-01-04     1.212171     1017.653427                30.277898
# 2008-01-05     3.918379     1013.838332                30.640481
#
#             pastWeatherIndicator  precipTime  precipDepth  snowDepth    year  \
# 2008-01-01              4.171073    5.199203    47.503108  21.776100  2008.0
# 2008-01-02              4.152460    5.355434    44.483105  22.627133  2008.0
# 2008-01-03              4.119097    5.402424    47.639126  23.396628  2008.0
# 2008-01-04              3.897811    5.524803    39.277930  22.328746  2008.0
# 2008-01-05              4.154117    5.342658    39.990708  23.943632  2008.0
#
#             day  version
# 2008-01-01  1.0      1.0
# 2008-01-02  2.0      1.0
# 2008-01-03  3.0      1.0
# 2008-01-04  4.0      1.0
# 2008-01-05  5.0      1.0

# %%
for col in list(means.columns):
    fig = plt.figure(figsize=(16, 8))
    #plt.style.use('dark_background')
    means[col].plot(color='b')
    plt.title('Average of {}'.format(col))
    plt.xlim([datetime(2008, 1, 1), datetime(2020, 2, 1)])
    plt.grid()
    
    # optionally, log the image to the run
    run.log_image(f'mean_{col}', plot=plt)

# %% [markdown]
# You can see the images logged to the run in the studio.

# %%
run
# Out:
# Run(Experiment: dask-demo,
# Id: dask-demo_1581036271_b9dadf22,
# Type: azureml.scriptrun,
# Status: Running)

# %% [markdown]
# ## Transform data

# %%
## insert any Pandas-like Dask transformation code 
df['temperature'] = df['temperature']*(9/5)+32 # 'Merica

# %% [markdown]
# ## Take subset of data to Pandas

# %%
df = df[df['stationName'].str.contains('FLORIDA|WASHINGTON|TEXAS', regex=True, na=False)].compute()
df
# Out:
#               usaf   wban            datetime  latitude  longitude  elevation  \
# 2008-01-04  725454  04903 2008-01-04 10:35:00    41.276    -91.667      230.0
# 2008-01-26  725454  04903 2008-01-26 04:15:00    41.276    -91.667      230.0
# 2008-01-08  725454  04903 2008-01-08 05:59:00    41.276    -91.667      230.0
# 2008-01-20  725454  04903 2008-01-20 02:35:00    41.276    -91.667      230.0
# 2008-01-30  725454  04903 2008-01-30 22:15:00    41.276    -91.667      230.0
# ...            ...    ...                 ...       ...        ...        ...
# 2020-02-03  998482  99999 2020-02-03 16:00:00    27.812    -97.390        8.0
# 2020-02-01  998482  99999 2020-02-01 03:00:00    27.812    -97.390        8.0
# 2020-02-03  998482  99999 2020-02-03 13:00:00    27.812    -97.390        8.0
# 2020-02-02  998482  99999 2020-02-02 11:00:00    27.812    -97.390        8.0
# 2020-02-02  998482  99999 2020-02-02 15:00:00    27.812    -97.390        8.0
#
#             windAngle  windSpeed  temperature  seaLvlPressure  ...  \
# 2008-01-04      200.0        6.7        28.40             NaN  ...
# 2008-01-26      170.0        4.6        26.60             NaN  ...
# 2008-01-08        NaN        NaN          NaN             NaN  ...
# 2008-01-20      270.0        2.6        -0.40             NaN  ...
# 2008-01-30       80.0        1.5        14.00             NaN  ...
# ...               ...        ...          ...             ...  ...
# 2020-02-03        0.0        0.0        67.82          1012.2  ...
# 2020-02-01        0.0        0.0        58.10          1022.6  ...
# 2020-02-03        0.0        0.0        63.32          1011.4  ...
# 2020-02-02        0.0        0.0        52.34          1022.2  ...
# 2020-02-02        0.0        0.0        53.78          1023.0  ...
#
#            pastWeatherIndicator  precipTime  precipDepth  snowDepth  \
# 2008-01-04                  NaN         NaN          NaN        NaN
# 2008-01-26                  NaN         NaN          NaN        NaN
# 2008-01-08                  NaN         NaN          NaN        NaN
# 2008-01-20                  NaN         NaN          NaN        NaN
# 2008-01-30                  NaN         NaN          NaN        NaN
# ...                         ...         ...          ...        ...
# 2020-02-03                  NaN         NaN          NaN        NaN
# 2020-02-01                  NaN         NaN          NaN        NaN
# 2020-02-03                  NaN         NaN          NaN        NaN
# 2020-02-02                  NaN         NaN          NaN        NaN
# 2020-02-02                  NaN         NaN          NaN        NaN
#
#                           stationName  countryOrRegion           p_k  year  \
# 2008-01-04  WASHINGTON MUNICIPAL ARPT               US  725454-04903  2008
# 2008-01-26  WASHINGTON MUNICIPAL ARPT               US  725454-04903  2008
# 2008-01-08  WASHINGTON MUNICIPAL ARPT               US  725454-04903  2008
# 2008-01-20  WASHINGTON MUNICIPAL ARPT               US  725454-04903  2008
# 2008-01-30  WASHINGTON MUNICIPAL ARPT               US  725454-04903  2008
# ...                               ...              ...           ...   ...
# 2020-02-03       TEXAS STATE AQUARIUM               US  998482-99999  2020
# 2020-02-01       TEXAS STATE AQUARIUM               US  998482-99999  2020
# 2020-02-03       TEXAS STATE AQUARIUM               US  998482-99999  2020
# 2020-02-02       TEXAS STATE AQUARIUM               US  998482-99999  2020
# 2020-02-02       TEXAS STATE AQUARIUM               US  998482-99999  2020
#
#            day  version
# 2008-01-04   4      1.0
# 2008-01-26  26      1.0
# 2008-01-08   8      1.0
# 2008-01-20  20      1.0
# 2008-01-30  30      1.0
# ...         ..      ...
# 2020-02-03   3      1.0
# 2020-02-01   1      1.0
# 2020-02-03   3      1.0
# 2020-02-02   2      1.0
# 2020-02-02   2      1.0
#
# [2785056 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2785056 entries, 2008-01-04 to 2020-02-02
# Data columns (total 22 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   usaf                     object
#  1   wban                     object
#  2   datetime                 datetime64[ns]
#  3   latitude                 float64
#  4   longitude                float64
#  5   elevation                float64
#  6   windAngle                float64
#  7   windSpeed                float64
#  8   temperature              float64
#  9   seaLvlPressure           float64
#  10  cloudCoverage            object
#  11  presentWeatherIndicator  float64
#  12  pastWeatherIndicator     float64
#  13  precipTime               float64
#  14  precipDepth              float64
#  15  snowDepth                float64
#  16  stationName              object
#  17  countryOrRegion          object
#  18  p_k                      object
#  19  year                     int32
#  20  day                      int32
#  21  version                  float64
# dtypes: datetime64[ns](1), float64(13), int32(2), object(6)
# memory usage: 467.5+ MB

# %% [markdown]
# ## Write data
#
# **Warning**: This will write ~150 GB of CSV files to your ADLSv2 storage account. This will be used to demonstrate Dask + Azure ML on an artificially larger set of files. This will take ~30 mins.

# %%
#%time df.to_csv(f'{protocol}://{container}/noaa-isd-csv/part-*-data.csv', storage_options=STORAGE_OPTIONS)

# %% [markdown]
# ## Train XGBoost model
#
# The below cells are for demo purposes only. The code is not good. The data science is not good.

# %%
# begin data prep for ML 
df = df.fillna(0)

# %%
cols = list(df.columns)
cols = [col for col in cols if df.dtypes[col] != 'object' and col not in ['version', 'datetime']]
cols

# %%
X = df[[col for col in cols if col not in ['temperature']]].persist()
y = df.temperature.persist()
# end data prep for ML

# %%
xgb = XGBRegressor(n_estimators=16)
# %time xgb.fit(X, y)

# %%
# %time y_pred = xgb.predict(X).compute()

# %%
rmse = (((y.to_dask_array().compute()-y_pred)**2).mean())**.5 # runs locally, distribute (?)
run.log('RMSE', rmse)
print(f'Training RMSE: {round(rmse, 3)}')

# %% [markdown]
# ## Register model

# %%
model_path = 'xgboost_noaa_isd.joblib.dat'
joblib.dump(xgb, model_path)
xgb = joblib.load(model_path)

# %%
model = Model.register(run.experiment.workspace, 
                       model_name      = 'xgboost-noaa-isd', 
                       model_path      = model_path,
                       description     = 'Dask XGBoost NOAA ISD temperature predictor',
                       model_framework = 'DaskML.XGBoostRegressor')
